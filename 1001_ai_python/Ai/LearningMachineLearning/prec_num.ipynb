# %% [markdown]
# Scatter Plot

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import random

# x = np.random.randint(10, 60, (50))
# print(x)

no = [56, 36, 42, 29, 10, 48, 17, 23, 14, 28, 18, 22, 49, 24, 56, 15, 30, 50, 34, 32, 53, 41, 33, 22, 53, 28, 29, 25, 21, 38, 20, 16, 22, 28, 59, 16, 33, 12, 26, 22, 53, 17, 49, 58, 32, 31, 14, 49, 50, 41]
l = [10,20,30,40,50,60]
plt.title("Histogram Plot", fontsize=15)
plt.xlabel('Python')
plt.ylabel('No.')


plt.hist(no,"auto", (0, 100), align="mid", rwidth=0.7, log=True)
# plt.hist(no,"auto", (0, 100), align="mid",orientation="horizontal", rwidth=0.7)
# plt.hist(no,"auto", (0, 100), align="mid",histtype="step")

plt.axvline(45, color='r', label="Mid")
plt.legend()
plt.grid()
plt.show()
