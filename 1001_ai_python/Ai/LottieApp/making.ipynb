# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as ec
from random_strings import random_string
import pandas as pd
import time
import pyperclip
import pyautogui
import shutil
import os
from bs4 import BeautifulSoup

rand_email = random_string(10)
rand_fname = random_string(13)
rand_lname = random_string(13)

try:
    # Read the last index from the file
    with open('email.csv', 'r') as file:
        last_index = int(file.readlines()[-1].split(',')[0])  # Read the last line of the file and extract the index
except (FileNotFoundError, IndexError, ValueError):
    # If the file doesn't exist, is empty, or has invalid content, start with index 0
    last_index = 0

# Increment the index
next_index = last_index + 1

# Get the email address from the user
email = f"{rand_email}@gmail.com"

# Append the next index and email to the file with a comma
with open('email.csv', 'a') as file:
    file.write(f'{next_index},{email}\n')

# Read the text file into a DataFrame with column names
df2 = pd.read_csv('email.csv', header=None, names=['Index', 'Email'])


driver = webdriver.Firefox()

# Get the page source using Selenium
page_source = driver.page_source

# Maximize the browser window
driver.maximize_window()

driver.get('https://accounts.lottiefiles.com/register?return_to=https://lottiefiles.com/getting-started')

wait = WebDriverWait(driver, 20)  # Increased timeout to 20 seconds

pyautogui.moveTo(303, 80) # Move the mouse to XY coordinates.

fname_input = wait.until(ec.visibility_of_element_located((By.NAME, "firstName")))
# click on firsname input box
fname_input.send_keys(rand_fname)

lname_input = wait.until(ec.visibility_of_element_located((By.NAME, "lastName")))
# click on firsname input box
lname_input.send_keys(rand_lname)

email_input = wait.until(ec.visibility_of_element_located((By.NAME, "email")))
# click on firsname input box
email_input.send_keys(email)

password_input = wait.until(ec.visibility_of_element_located((By.NAME, "password")))
# click on firsname input box
password_input.send_keys("-A1li@sge3939")

register_btn = wait.until(ec.visibility_of_element_located((By.XPATH, "/html/body/div[1]/div/div/div[2]/div/div/div/div/form/div/div/div[5]/button")))
# click on firsname input box
register_btn.click()

des = wait.until(ec.visibility_of_element_located((By.XPATH,"/html/body/div[4]/div[2]/div/div/div/div/div[3]/div")))
# click on firsname input box
des.click()

cont = wait.until(ec.visibility_of_element_located((By.XPATH,"/html/body/div[4]/div[3]/button")))
# click on firsname input box
cont.click()

time.sleep(5)

goToDashboard = wait.until(ec.element_to_be_clickable((By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div[2]/div/div[2]/div/div[1]/a")))
# click on firsname input box
goToDashboard.click()


# Parse the page source with BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# 1. Open a text file in write mode
file_path = "soup.txt"
with open(file_path, "w") as file:
    file.write(soup)

# # Find the button element using BeautifulSoup and XPath
# button_xpath = '/html/body/div[1]/button'  # Replace with the actual XPath of the button
# button = soup.find('button', {'xpath': button_xpath})

# if button:
#     print("Button found!")
#     # You can interact with the 'button' BeautifulSoup object here
#     # For example, you can get the button's text using button.text
# else:
#     print("Button not found!")
# kp = wait.until(ec.element_to_be_clickable((By.XPATH,"/html/body/div[1]/div[2]/div[1]/div/div[2]/div[2]/div[1]/div/div/div[1]/div/div/div[3]/div[1]")))
# # click on firsname input box
# kp.click()

# time.sleep(5)
# pyautogui.click(565, 359)


# select_file_btn = wait.until(ec.visibility_of_element_located((By.XPATH,"/html/body/div[6]/div/div[2]/div[2]/div[3]/div/div[1]/div")))
# # click on firsname input box
# select_file_btn.click()

# time.sleep(1)
# image = 'stats.json'
# imagePath = r'C:\Users\Aliasger B\Downloads'

# screenWidth, screenHeight = pyautogui.size()

# pyautogui.click(312, 48)
# # Select all text (Ctrl + A)
# pyautogui.hotkey('ctrl', 'a')

# # Delete the selected text (Backspace)
# pyautogui.press('backspace')
# pyautogui.write(imagePath, interval=0.025)
# pyautogui.press('enter')
# pyautogui.click(256, 415)
# pyautogui.write(image, interval=0.025)
# pyautogui.click(561, 445)
# time.sleep(2)
# driver.quit()
# df2
# Out:
# The version of firefox cannot be detected. Trying with latest driver version
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[6], line 76
#      73 # click on firsname input box
#      74 register_btn.click()
# ---> 76 des = wait.until(ec.visibility_of_element_located((By.XPATH,"/html/body/div[4]/div[2]/div/div/div/div/div[3]/div")))
#      77 # click on firsname input box
#      78 des.click()
#
# File c:\Users\Aliasger B\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\support\wait.py:95, in WebDriverWait.until(self, method, message)
#      93     if time.monotonic() > end_time:
#      94         break
# ---> 95 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# ...
