# %%
import pandas as pd

# %%
dataset = pd.read_csv('datasets/noble_prize_dataset/nobel.csv')

# %%
dataset
# Out:
#           firstname    surname born_country_code died_country_code  gender  \
# 0    Wilhelm Conrad    Röntgen                DE                DE    male
# 1        Hendrik A.    Lorentz                NL                NL    male
# 2            Pieter     Zeeman                NL                NL    male
# 3             Henri  Becquerel                FR                FR    male
# 4            Pierre      Curie                FR                FR    male
# ..              ...        ...               ...               ...     ...
# 918           Peter     Handke                AT               NaN    male
# 919            Abiy  Ahmed Ali                ET               NaN    male
# 920         Abhijit   Banerjee                IN               NaN    male
# 921          Esther      Duflo                FR               NaN  female
# 922         Michael     Kremer                US               NaN    male
#
#      year    category  share  \
# 0    1901     physics      1
# ...

# %%
x = dataset[['firstname','surname' ,'born_country_code','died_country_code','year','category','share','name_of_university','city_of_university','country_of_university','born_month','age','age_get_prize']].values

# %%
x
# Out:
# array([['Wilhelm Conrad', 'Röntgen', 'DE', ..., 'Mar', 78, 56],
#        ['Hendrik A.', 'Lorentz', 'NL', ..., 'Jul', 75, 49],
#        ['Pieter', 'Zeeman', 'NL', ..., 'May', 78, 37],
#        ...,
#        ['Abhijit', 'Banerjee', 'IN', ..., 'Feb', 59, 58],
#        ['Esther', 'Duflo', 'FR', ..., 'Oct', 48, 47],
#        ['Michael', 'Kremer', 'US', ..., 'Nov', 56, 55]], dtype=object)

# %%
y = dataset[['gender']].values

# %%
y
# Out:
# array([['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['female'],
#        ['female'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
#        ['male'],
# ...

# %%
from sklearn.impute import SimpleImputer
# import numpy as np

# %%
imputer = SimpleImputer(missing_values=np.nan,
    strategy='mean')

# %%
imputer = imputer.fit(x[:, 1 : 4])
